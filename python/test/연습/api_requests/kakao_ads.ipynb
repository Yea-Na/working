# %%
import requests
import json
import pandas as pd

# url = "https://kauth.kakao.com/oauth/token"

# data = {
#     "grant_type" : "authorization_code",
#     "client_id" : "e50e5da51efd8d9e160d28c0bace2dac",
#     "redirect_uri" : "https://example.com/oauth",
#     "code"         : token
# }
# response = requests.post(url, data=data)

# tokens = response.json()

# print(tokens)

# %% [markdown]
# ## kakao 토큰 재발급 및 앱 갱신하는 방법
# 1. redircet uri 접속해서 값 추출
# 2. uri에서 발급한 토큰 집어넣기
# 3. 필요한 app id 별로 데이터 추출하기

# %%
url = "https://kauth.kakao.com/oauth/authorize?client_id=e50e5da51efd8d9e160d28c0bace2dac&response_type=code&redirect_uri=https://example.com/oauth"

response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
token = 'ANMh-JFXF9GBEzxNc1k29vimUAzbzQv-Hvg6gmtLCinI2QAAAYFGDaJC'

# %%
url = "https://kauth.kakao.com/oauth/token"

data = {
    "grant_type" : "authorization_code",
    "client_id" : "d8d64057b82a540d7bfc46b8c2512fb5",
    "redirect_uri" : "https://example.com/oauth",
    "code"         : token
}
response = requests.post(url, data=data)

tokens = response.json()

print(tokens)
# Out:
# {'error': 'invalid_client', 'error_description': 'To use Kakao account login, user management has to be configured.', 'error_code': 'KOE004'}

# %%
access_token = 'XozLRBLYVEUfolUJA0riqzZosVGciKwgNmf-DMkoCisNHgAAAYFGEJbI'

# %%
url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report"


header = {'Authorization': 'Bearer ${}'.format(access_token), 'adAccountId':'444477'}
parameter = {'dataPreset' : 'TODAY', 'timeUnit' : 'DAY'}
response = requests.get(url, headers=header, params = parameter) 
test = response.json()

print(response)
print(test)
# Out:
# <Response [200]>
# {'code': 200, 'message': 'Success', 'data': [{'start': '2022-06-09', 'end': '2022-06-09', 'dimensions': {}, 'metrics': {}}]}

# %%
#당일 시간대별 데이터 
# url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report?datePreset=TODAY&level=AD_ACCOUNT&dimension=CREATIVE_FORMAT&metricsGroup=BASIC"
url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report"


header = {'Authorization': 'Bearer ${XozLRBLYVEUfolUJA0riqzZosVGciKwgNmf-DMkoCisNHgAAAYFGEJbI}', 'adAccountId':'444477'}
parameter = {'dataPreset' : 'TODAY', 'timeUnit' : 'DAY', 'dimension' : 'HOUR'}
response = requests.get(url, headers=header, params = parameter) 
test = response.json()

print(response)
print(test)
# Out:
# <Response [200]>
# {'code': 200, 'message': 'Success', 'data': [{'start': '2022-06-09', 'end': '2022-06-09', 'dimensions': {}, 'metrics': {}}]}

# %%
# url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report?datePreset=TODAY&level=AD_ACCOUNT&dimension=CREATIVE_FORMAT&metricsGroup=BASIC"
url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report"


header = {'Authorization': 'Bearer ${}'.format(access_token), 'adAccountId':'422292'}
parameter = {'dataPreset' : 'TODAY', 'timeUnit' : 'DAY'}
response = requests.get(url, headers=header, params = parameter) 
test = response.json()
  
print(response)
print(test)
# Out:
# <Response [200]>
# {'code': 200, 'message': 'Success', 'data': [{'start': '2022-04-27', 'end': '2022-04-27', 'dimensions': {'ad_account_id': '422292'}, 'metrics': {'imp': 27888, 'click': 183, 'ctr': 0.656, 'cost': 73744.0, 'video_play_3s': 0}}]}

# %%
# Out:
# <Response [200]>
# {'content': [{'id': 394067, 'name': '일룸_데스커브랜드', 'memberType': 'MEMBER', 'config': 'ON'}, {'id': 390224, 'name': '시디즈_알로소', 'memberType': 'MEMBER', 'config': 'ON'}, {'id': 386912, 'name': '일룸_일룸', 'memberType': 'MEMBER', 'config': 'OFF'}, {'id': 422292, 'name': '일룸_슬로우', 'memberType': 'MEMBER', 'config': 'ON'}]}

# %%
# Out:
# [{'id': 394067, 'name': '일룸_데스커브랜드', 'memberType': 'MEMBER', 'config': 'ON'},
#  {'id': 390224, 'name': '시디즈_알로소', 'memberType': 'MEMBER', 'config': 'ON'},
#  {'id': 386912, 'name': '일룸_일룸', 'memberType': 'MEMBER', 'config': 'OFF'},
#  {'id': 422292, 'name': '일룸_슬로우', 'memberType': 'MEMBER', 'config': 'ON'}]

# %%
test.get('data')[0].get('metrics')
# Out:
# {'imp': 24926, 'click': 171, 'ctr': 0.686, 'cost': 68893.0, 'video_play_3s': 0}

# %%
###  파라미터 테스트

# %%
# url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report?datePreset=TODAY&level=AD_ACCOUNT&dimension=CREATIVE_FORMAT&metricsGroup=BASIC"
url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report"


header = {'Authorization': 'Bearer ${}'.format(access_token), 'adAccountId':'422292'}
parameter = {'dataPreset' : 'TODAY',
             'timeUnit' : 'DAY',
             'level' : 'CAMPAIGN'
             }
response = requests.get(url, headers=header, params = parameter) 
test = response.json()

print(response)
print(test)
# Out:
# <Response [200]>
# {'code': 200, 'message': 'Success', 'data': [{'start': '2022-04-27', 'end': '2022-04-27', 'dimensions': {'campaign_id': '767418'}, 'metrics': {'imp': 31917, 'click': 200, 'ctr': 0.627, 'cost': 80608.0, 'video_play_3s': 0}}]}

# %%
## 보고서 단위 테스트(계정단위)
# url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report?datePreset=TODAY&level=AD_ACCOUNT&dimension=CREATIVE_FORMAT&metricsGroup=BASIC"
url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report"


header = {'Authorization': 'Bearer ${}'.format(access_token), 'adAccountId':'444477'}
parameter = {'dataPreset' : 'TODAY',
             'timeUnit' : 'DAY',
             'level' : 'CAMPAIGN',
             'dimension' : 'CREATIVE_FORMAT',
             'metricsGroup' : 'BASIC,ADDITION'
             }
response = requests.get(url, headers=header, params = parameter) 
test = response.json()

print(response)
print(test)
# Out:
# <Response [200]>
# {'code': 200, 'message': 'Success', 'data': [{'start': '2022-06-09', 'end': '2022-06-09', 'dimensions': {}, 'metrics': {}}]}

# %%
## 보고서 단위 테스트(캠페인단위)
# url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report?datePreset=TODAY&level=AD_ACCOUNT&dimension=CREATIVE_FORMAT&metricsGroup=BASIC"
url = "https://apis.moment.kakao.com/openapi/v4/campaigns/report"


header = {'Authorization': 'Bearer ${}'.format(access_token), 'adAccountId': str(adAccount_id)}
parameter = {'campaignId' : '752050',
             'datePreset' : 'TODAY',
             'timeUnit' : 'DAY',
             'level' : 'AD_GROUP',
             'dimension' : 'HOUR',
             'metricsGroup' : 'BASIC,ADDITION'
             }
response = requests.get(url, headers=header, params = parameter) 
test = response.json()

print(response)
print(test)
# Out:
# <Response [200]>
# ...

# %%
## 보고서 단위 테스트(광고그룹단위)
# url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report?datePreset=TODAY&level=AD_ACCOUNT&dimension=CREATIVE_FORMAT&metricsGroup=BASIC"
url = "https://apis.moment.kakao.com/openapi/v4/adGroups/report"


header = {'Authorization': 'Bearer ${}'.format(access_token), 'adAccountId': str(adAccount_id)}
parameter = {'adGroupId' : '2008512',
             'datePreset' : 'TODAY',
             'timeUnit' : 'DAY',
             'level' : 'AD_GROUP',
             'dimension' : 'HOUR',
             'metricsGroup' : 'BASIC,ADDITION'
             }
response = requests.get(url, headers=header, params = parameter) 
test = response.json()

print(response)
print(test)
# Out:
# <Response [200]>
# ...

# %%
## 광고계정 목록 조회
# url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report?datePreset=TODAY&level=AD_ACCOUNT&dimension=CREATIVE_FORMAT&metricsGroup=BASIC"
url = "https://apis.moment.kakao.com/openapi/v4/adAccounts"


header = {'Authorization': 'Bearer ${}'.format(access_token)}#, 'adAccountId':'422292'}
parameter = {'dataPreset' : 'TODAY', 'timeUnit' : 'DAY'}
response = requests.get(url, headers=header)#, params = parameter) 
test = response.json()

print(response)
print(test)
test.get('content')
# Out:
# <Response [200]>
# {'content': [{'id': 394067, 'name': '일룸_데스커브랜드', 'memberType': 'MEMBER', 'config': 'ON'}, {'id': 390224, 'name': '시디즈_알로소', 'memberType': 'MEMBER', 'config': 'ON'}, {'id': 386912, 'name': '일룸_일룸', 'memberType': 'MEMBER', 'config': 'OFF'}, {'id': 422292, 'name': '일룸_슬로우', 'memberType': 'MEMBER', 'config': 'ON'}]}
# [{'id': 394067, 'name': '일룸_데스커브랜드', 'memberType': 'MEMBER', 'config': 'ON'},
#  {'id': 390224, 'name': '시디즈_알로소', 'memberType': 'MEMBER', 'config': 'ON'},
#  {'id': 386912, 'name': '일룸_일룸', 'memberType': 'MEMBER', 'config': 'OFF'},
#  {'id': 422292, 'name': '일룸_슬로우', 'memberType': 'MEMBER', 'config': 'ON'}]

# %%
adAccount_id = test.get('content')[0].get('id')
adAccount_id
# Out:
# 394067

# %%
## 캠페인 목록 보기
# url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report?datePreset=TODAY&level=AD_ACCOUNT&dimension=CREATIVE_FORMAT&metricsGroup=BASIC"
url = "https://apis.moment.kakao.com/openapi/v4/campaigns"


header = {'Authorization': 'Bearer ${}'.format(access_token), 'adAccountId': str(adAccount_id)}
# parameter = {'config' : 'ON'             }
response = requests.get(url, headers=header)#, params = parameter) 
test = response.json()

print(response)
print(test)
# Out:
# <Response [200]>
# {'content': [{'id': 732262, 'name': '220228_상시운영(스마트스토어)', 'userConfig': 'OFF', 'adminStop': False, 'config': 'OFF'}, {'id': 734940, 'name': '220307_디스플레이_기획전(오늘의집)', 'userConfig': 'OFF', 'adminStop': False, 'config': 'OFF'}, {'id': 740060, 'name': '220314_기획전(스마트스토어)', 'userConfig': 'OFF', 'adminStop': False, 'config': 'OFF'}, {'id': 745359, 'name': '220321_기획전(오늘의집)_디스플레이', 'userConfig': 'OFF', 'adminStop': False, 'config': 'OFF'}, {'id': 752050, 'name': '220401_상시운영(스마트스토어)', 'userConfig': 'ON', 'adminStop': False, 'config': 'ON'}, {'id': 752052, 'name': '220404_기획전(오늘의집)', 'userConfig': 'OFF', 'adminStop': False, 'config': 'OFF'}, {'id': 763739, 'name': '220418_기획전(스마트스토어)', 'userConfig': 'OFF', 'adminStop': False, 'config': 'OFF'}]}

# %%
campain_id = test.get('content')[0].get('id')
campain_id
# Out:
# 732262

# %%
## 광고그룹 목록 보기
# url = "https://apis.moment.kakao.com/openapi/v4/adAccounts/report?datePreset=TODAY&level=AD_ACCOUNT&dimension=CREATIVE_FORMAT&metricsGroup=BASIC"
url = "https://apis.moment.kakao.com/openapi/v4/adGroups"


header = {'Authorization': 'Bearer ${}'.format(access_token), 'adAccountId': str(adAccount_id)}
parameter = {'campaignId' : '752050'             }
response = requests.get(url, headers=header, params = parameter) 
test = response.json()

print(response)
print(test)
# Out:
# <Response [200]>
# {'content': [{'id': 2006372, 'name': '디스플레이_Seg2(신혼)', 'userConfig': 'ON', 'adminStop': False, 'config': 'ON'}, {'id': 2008512, 'name': '디스플레이_Seg3(1인)', 'userConfig': 'ON', 'adminStop': False, 'config': 'ON'}, {'id': 2008509, 'name': '디스플레이_Seg1', 'userConfig': 'ON', 'adminStop': False, 'config': 'ON'}]}

# %%
#### for 문

## 광고계정 목록 조회
adAccounts_url = "https://apis.moment.kakao.com/openapi/v4/adAccounts"


header = {'Authorization': 'Bearer ${}'.format(access_token)}#, 'adAccountId':'422292'}
parameter = {'dataPreset' : 'TODAY', 'timeUnit' : 'DAY'}
response = requests.get(adAccounts_url, headers=header)#, params = parameter) 
test = response.json()

print(response)
print(test)
test.get('content')


adAccount_id = test.get('content')[0].get('id')
adAccount_id
# Out:
# <Response [200]>
# {'content': [{'id': 394067, 'name': '일룸_데스커브랜드', 'memberType': 'MEMBER', 'config': 'ON'}, {'id': 390224, 'name': '시디즈_알로소', 'memberType': 'MEMBER', 'config': 'ON'}, {'id': 386912, 'name': '일룸_일룸', 'memberType': 'MEMBER', 'config': 'OFF'}, {'id': 422292, 'name': '일룸_슬로우', 'memberType': 'MEMBER', 'config': 'ON'}]}
# 394067

# %%
print(test.get('data')[0])
print(test)
# Out:
# {'start': '2022-04-27', 'end': '2022-04-27', 'dimensions': {'ad_group_id': '2008512', 'hour': '00:00~00:59'}, 'metrics': {'imp': 1821, 'click': 8, 'ctr': 0.439, 'cost': 2475.0, 'video_play_3s': 0, 'reach': 1108, 'cost_per_imp': 1.359, 'cost_per_click': 309.375, 'cost_per_reach': 2.234, 'cost_per_video_play_3s': 0.0}}
# ...

# %%
print(test.get('message'))
print(test.get('data'))
print(test.get('data').get(dimensions))
print(test)
# Out:
# Success
# ...

# %%
df = pd.DataFrame(test.get('data'))
# df.get('data')
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\yeana shin\Downloads\kakao_ads.ipynb Cell 28' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yeana%20shin/Downloads/kakao_ads.ipynb#ch0000027?line=0'>1</a> df = pd.DataFrame(test.get)
#       <a href='vscode-notebook-cell:/c%3A/Users/yeana%20shin/Downloads/kakao_ads.ipynb#ch0000027?line=1'>2</a> # df.get('data')
#       <a href='vscode-notebook-cell:/c%3A/Users/yeana%20shin/Downloads/kakao_ads.ipynb#ch0000027?line=2'>3</a> df
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:756, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=752'>753</a> # For data is scalar
# ...

# %%
df1 = pd.DataFrame(test.get('data'))
# df2 = pd.DataFrame(test.get('message'))
df3 = pd.DataFrame(test.get('data').get('dimensions'))
# df4 = pd.DataFrame(print(test))
df1['message'] = test.get('message')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\yeana shin\Downloads\kakao_ads.ipynb Cell 29' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/yeana%20shin/Downloads/kakao_ads.ipynb#ch0000028?line=0'>1</a> df1 = pd.DataFrame(test.get('data'))
#       <a href='vscode-notebook-cell:/c%3A/Users/yeana%20shin/Downloads/kakao_ads.ipynb#ch0000028?line=1'>2</a> # df2 = pd.DataFrame(test.get('message'))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yeana%20shin/Downloads/kakao_ads.ipynb#ch0000028?line=2'>3</a> df3 = pd.DataFrame(test.get('data').get('dimensions'))
#       <a href='vscode-notebook-cell:/c%3A/Users/yeana%20shin/Downloads/kakao_ads.ipynb#ch0000028?line=3'>4</a> # df4 = pd.DataFrame(print(test))
# ...

# %%
df1.tail()
# Out:
#         start         end                                         dimensions  \
# 0  2022-04-27  2022-04-27  {'ad_group_id': '2006372', 'hour': '00:00~00:59'}
# 1  2022-04-27  2022-04-27  {'ad_group_id': '2006372', 'hour': '01:00~01:59'}
# 2  2022-04-27  2022-04-27  {'ad_group_id': '2006372', 'hour': '07:00~07:59'}
# 3  2022-04-27  2022-04-27  {'ad_group_id': '2006372', 'hour': '08:00~08:59'}
# 4  2022-04-27  2022-04-27  {'ad_group_id': '2006372', 'hour': '09:00~09:59'}
#
#                                              metrics
# 0  {'imp': 1197, 'click': 9, 'ctr': 0.752, 'cost'...
# 1  {'imp': 680, 'click': 8, 'ctr': 1.176, 'cost':...
# 2  {'imp': 1660, 'click': 9, 'ctr': 0.542, 'cost'...
# 3  {'imp': 1927, 'click': 13, 'ctr': 0.675, 'cost...
# 4  {'imp': 2174, 'click': 8, 'ctr': 0.368, 'cost'...
