# %%
import streamlit as st
st.set_page_config(layout="wide")

import pandas as pd
import numpy as np

st.title('Uber pickups in NYC')

DATE_COLUMN = 'date/time'
DATA_URL = ('https://s3-us-west-2.amazonaws.com/'
            'streamlit-demo-data/uber-raw-data-sep14.csv.gz')

@st.cache
def load_data(nrows):
    data = pd.read_csv(DATA_URL, nrows=nrows)
    lowercase = lambda x: str(x).lower()
    data.rename(lowercase, axis='columns', inplace=True)
    data[DATE_COLUMN] = pd.to_datetime(data[DATE_COLUMN])
    return data

data_load_state = st.text('Loading data...')
data = load_data(10000)
data_load_state.text("Done! (using st.cache)")

if st.checkbox('Show raw data'):
    st.subheader('Raw data')
    st.write(data)

st.subheader('Number of pickups by hour')
hist_values = np.histogram(data[DATE_COLUMN].dt.hour, bins=24, range=(0,24))[0]
st.bar_chart(hist_values)

hour_to_filter = st.slider('hour', 0, 23, 17)
filtered_data = data[data[DATE_COLUMN].dt.hour == hour_to_filter]

st.subheader('Map of all pickups at %s:00' % hour_to_filter)
st.map(filtered_data)
# Out:
# 2022-05-20 11:09:32.860
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\yeana shin\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\hashing.py:368, in _CodeHasher.to_bytes(self, obj, context)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=365'>366</a> try:
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=366'>367</a>     # Hash the input
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=367'>368</a>     b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=369'>370</a>     # Hmmm... It's possible that the size calculation is wrong. When we
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=370'>371</a>     # call to_bytes inside _to_bytes things get double-counted.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\hashing.py:634, in _CodeHasher._to_bytes(self, obj, context)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=632'>633</a> assert code is not None
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=633'>634</a> if self._file_should_be_hashed(code.co_filename):
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=634'>635</a>     context = _get_context(obj)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\hashing.py:410, in _CodeHasher._file_should_be_hashed(self, filename)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=407'>408</a>     return False
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=408'>409</a> return file_util.file_is_in_folder_glob(
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=409'>410</a>     filepath, self._get_main_script_directory()
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=410'>411</a> ) or file_util.file_in_pythonpath(filepath)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\hashing.py:721, in _CodeHasher._get_main_script_directory()
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=718'>719</a> # This works because we set __main__.__file__ to the
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=719'>720</a> # script path in ScriptRunner.
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=720'>721</a> main_path = __main__.__file__
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=721'>722</a> return str(os.path.dirname(main_path))
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# c:\Users\yeana shin\Desktop\workspace\workspace\python\test\dash_test\streamlit_test.ipynb Cell 1' in <cell line: 20>()
#      <a href='vscode-notebook-cell:/c%3A/Users/yeana%20shin/Desktop/workspace/workspace/python/test/dash_test/streamlit_test.ipynb#ch0000000?line=16'>17</a>     return data
#      <a href='vscode-notebook-cell:/c%3A/Users/yeana%20shin/Desktop/workspace/workspace/python/test/dash_test/streamlit_test.ipynb#ch0000000?line=18'>19</a> data_load_state = st.text('Loading data...')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/yeana%20shin/Desktop/workspace/workspace/python/test/dash_test/streamlit_test.ipynb#ch0000000?line=19'>20</a> data = load_data(10000)
#      <a href='vscode-notebook-cell:/c%3A/Users/yeana%20shin/Desktop/workspace/workspace/python/test/dash_test/streamlit_test.ipynb#ch0000000?line=20'>21</a> data_load_state.text("Done! (using st.cache)")
#      <a href='vscode-notebook-cell:/c%3A/Users/yeana%20shin/Desktop/workspace/workspace/python/test/dash_test/streamlit_test.ipynb#ch0000000?line=22'>23</a> if st.checkbox('Show raw data'):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\caching.py:573, in cache.<locals>.wrapped_func(*args, **kwargs)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=570'>571</a> if show_spinner:
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=571'>572</a>     with st.spinner(message):
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=572'>573</a>         return get_or_create_cached_value()
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=573'>574</a> else:
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=574'>575</a>     return get_or_create_cached_value()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\caching.py:498, in cache.<locals>.wrapped_func.<locals>.get_or_create_cached_value()
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=490'>491</a> nonlocal cache_key
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=491'>492</a> if cache_key is None:
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=492'>493</a>     # Delay generating the cache key until the first call.
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=493'>494</a>     # This way we can see values of globals, including functions
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=494'>495</a>     # defined after this one.
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=495'>496</a>     # If we generated the key earlier we would only hash those
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=496'>497</a>     # globals by name, and miss changes in their code or value.
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=497'>498</a>     cache_key = _hash_func(func, hash_funcs)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=499'>500</a> # First, get the cache that's attached to this function.
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=500'>501</a> # This cache's key is generated (above) from the function's code.
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=501'>502</a> mem_cache = _mem_caches.get_cache(cache_key, max_entries, ttl)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\caching.py:624, in _hash_func(func, hash_funcs)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=612'>613</a> update_hash(
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=613'>614</a>     (func.__module__, func.__qualname__),
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=614'>615</a>     hasher=func_hasher,
#    (...)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=617'>618</a>     hash_source=func,
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=618'>619</a> )
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=620'>621</a> # Include the function's body in the hash. We *do* pass hash_funcs here,
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=621'>622</a> # because this step will be hashing any objects referenced in the function
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=622'>623</a> # body.
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=623'>624</a> update_hash(
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=624'>625</a>     func,
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=625'>626</a>     hasher=func_hasher,
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=626'>627</a>     hash_funcs=hash_funcs,
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=627'>628</a>     hash_reason=HashReason.CACHING_FUNC_BODY,
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=628'>629</a>     hash_source=func,
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=629'>630</a> )
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=630'>631</a> cache_key = func_hasher.hexdigest()
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=631'>632</a> _LOGGER.debug(
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=632'>633</a>     "mem_cache key for %s.%s: %s", func.__module__, func.__qualname__, cache_key
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/caching.py?line=633'>634</a> )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\hashing.py:116, in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=112'>113</a> hash_stacks.current.hash_source = hash_source
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=114'>115</a> ch = _CodeHasher(hash_funcs)
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=115'>116</a> ch.update(hasher, val, context)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\hashing.py:393, in _CodeHasher.update(self, hasher, obj, context)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=390'>391</a> def update(self, hasher, obj: Any, context: Optional[Context] = None) -> None:
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=391'>392</a>     """Update the provided hasher with the hash of an object."""
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=392'>393</a>     b = self.to_bytes(obj, context)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=393'>394</a>     hasher.update(b)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\hashing.py:382, in _CodeHasher.to_bytes(self, obj, context)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=378'>379</a>     raise
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=380'>381</a> except BaseException as e:
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=381'>382</a>     raise InternalHashError(e, obj)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=383'>384</a> finally:
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=384'>385</a>     # In case an UnhashableTypeError (or other) error is thrown, clean up the
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=385'>386</a>     # stack so we don't get false positives in future hashing calls
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=386'>387</a>     hash_stacks.current.pop()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\hashing.py:368, in _CodeHasher.to_bytes(self, obj, context)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=363'>364</a> hash_stacks.current.push(obj)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=365'>366</a> try:
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=366'>367</a>     # Hash the input
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=367'>368</a>     b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=369'>370</a>     # Hmmm... It's possible that the size calculation is wrong. When we
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=370'>371</a>     # call to_bytes inside _to_bytes things get double-counted.
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=371'>372</a>     self.size += sys.getsizeof(b)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\hashing.py:634, in _CodeHasher._to_bytes(self, obj, context)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=631'>632</a> code = getattr(obj, "__code__", None)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=632'>633</a> assert code is not None
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=633'>634</a> if self._file_should_be_hashed(code.co_filename):
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=634'>635</a>     context = _get_context(obj)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=635'>636</a>     defaults = getattr(obj, "__defaults__", None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\hashing.py:410, in _CodeHasher._file_should_be_hashed(self, filename)
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=406'>407</a> if file_is_blacklisted:
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=407'>408</a>     return False
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=408'>409</a> return file_util.file_is_in_folder_glob(
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=409'>410</a>     filepath, self._get_main_script_directory()
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=410'>411</a> ) or file_util.file_in_pythonpath(filepath)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\streamlit\legacy_caching\hashing.py:721, in _CodeHasher._get_main_script_directory()
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=716'>717</a> import os
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=718'>719</a> # This works because we set __main__.__file__ to the
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=719'>720</a> # script path in ScriptRunner.
# --> <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=720'>721</a> main_path = __main__.__file__
#     <a href='file:///c%3A/Users/yeana%20shin/AppData/Local/Programs/Python/Python310/lib/site-packages/streamlit/legacy_caching/hashing.py?line=721'>722</a> return str(os.path.dirname(main_path))
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `load_data()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function load_data at 0x0000023B18E8D360>
# ```
#
# Please see the `hash_funcs` [documentation]
# (https://docs.streamlit.io/library/advanced-features/caching#the-hash_funcs-parameter)
# for more details.
